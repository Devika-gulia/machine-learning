# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\devik\.conda\envs\adk_env\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\devik\.conda\envs\adk_env\lib\site-packages (2.2.6)

# %%
import pandas as pd

# %%
import numpy as np

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\devik\.conda\envs\adk_env\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\devik\.conda\envs\adk_env\lib\site-packages (from scikit-learn) (3.6.0)

# %%
df = pd.read_csv('cars.csv')

# %%
df.sample(5)
# Out:
#          brand  km_driven    fuel        owner  selling_price
# 5869  Mahindra     120000  Diesel  First Owner         700000
# 7602    Maruti      59000  Diesel  First Owner         765000
# 6098   Renault     120000  Diesel  First Owner         520000
# 752     Toyota     126000  Diesel  Third Owner         290000
# 5446    Maruti      71000  Diesel  First Owner         710000

# %%
#pd.get_dummies(df,columns = ['fuel','owner'],drop_first = True)

# %%
# ohe using frequent categories
counts = df['brand'].value_counts()
threshold = 100
repl = counts[counts <= threshold].index
mp = pd.get_dummies(df['brand'].replace(repl,'uncommon') ,drop_first = True)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,:-1],df.iloc[:,-1],test_size = 0.2)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
x_train_new = ohe.fit_transform(x_train[['fuel','owner']]).toarray()
x_test_new = ohe.fit_transform(x_test[['fuel','owner']]).toarray()
xl = np.hstack((x_train[['brand','km_driven']].values,x_train_new))

# %%
#xl.shape
