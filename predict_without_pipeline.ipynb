# %%
import pickle 
import numpy as np

# %%
ohe_sex = pickle.load(open('ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('ohe_embarked.pkl','rb'))
clf = pickle.load(open('clf.pkl','rb'))

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
# we have to separate age as well because we have to pass data in our model only as per the sequence given while training the model
test_input_age = test_input[:,2].reshape(1,1)
# now concatenate 
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed.shape
clf.predict(test_input_transformed)
# Out:
# array([1], dtype=int64)
